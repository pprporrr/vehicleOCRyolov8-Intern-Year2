# %%
from ultralytics import YOLO

model = YOLO('yolov8m.yaml')
model = YOLO('yolov8m.pt')
model = YOLO('yolov8m.yaml').load('yolov8m.pt')

model.train(data='data_custom.yaml', batch=8, epochs=5, imgsz=640, name='yolov8mCustom')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
# ...

# %%
from ultralytics import YOLO
model = YOLO('/Users/ppr/Desktop/Project/Intern-Year2_3/runs/detect/yolov8mCustom/weights/best.pt')

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.0.119 🚀 Python-3.9.16 torch-2.0.1 CPU
# YOLOv8m summary (fused): 218 layers, 25871026 parameters, 0 gradients, 78.9 GFLOPs
# val: Scanning /Users/ppr/Desktop/Project/Intern-Year2_3/datasets/val/labels.cache... 16610 images, 0 backgrounds, 0 corrupt: 100%|██████████| 16610/16610 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1039/1039 [1:46:06<00:00,  6.13s/it]
#                    all      16610     104290      0.945      0.931      0.933        0.9
#                      0      16610       4764      0.999      0.996      0.995      0.969
#                      1      16610       8238      0.998      0.999      0.995      0.939
#                      2      16610       7840          1          1      0.995      0.963
#                      3      16610       7050      0.998      0.999      0.995      0.971
# ...

# %%
metrics = model.val(split='train')
# Out:
# Ultralytics YOLOv8.0.119 🚀 Python-3.9.16 torch-2.0.1 CPU
# val: Scanning /Users/ppr/Desktop/Project/Intern-Year2_3/datasets/train/labels.cache... 58133 images, 0 backgrounds, 0 corrupt: 100%|██████████| 58133/58133 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3634/3634 [6:12:03<00:00,  6.14s/it]
#                    all      58133     365006      0.936      0.898      0.903      0.869
#                      0      58133      16458      0.999      0.997      0.995      0.969
#                      1      58133      28512      0.999      0.998      0.995      0.941
#                      2      58133      27491          1      0.999      0.995      0.963
#                      3      58133      25019      0.999      0.999      0.995      0.971
#                      4      58133      24977          1          1      0.995      0.965
# ...
